# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.plot(df.area, df.price)
plt.show()

# %%
plt.scatter(df.area, df.price)
plt.show()

# %%
X = df.drop("price", axis="columns") #independent feature
X.head()
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y = df.price #dependent feature
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     520000
# 6     490000
# 7     500000
# 8     450000
# 9     452100
# 10    320005
# 11    352525
# 12    305256
# 13    540253
# 14    524569
# 15    456286
# 16    442568
# 17    650253
# 18    562520
# 19    550000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()   #objcet creation
lin_reg.fit(X,y)        #model training
# Out:
# LinearRegression()

# %%
lin_reg.predict([[3300]])
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([608298.87614145])

# %%
lin_reg.predict([[1230]])
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([375143.91385452])

# %%
lin_reg.coef_ #slope m
# Out:
# array([112.63524748])

# %%
lin_reg.intercept_ #intercept b
# Out:
# 236602.55945214216

# %%
price = lin_reg.coef_ *3300 + lin_reg.intercept_
price
# Out:
# array([608298.87614145])
